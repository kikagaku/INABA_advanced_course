# %% [markdown]
# # -- イントロダクション --

# %% [markdown]
# ## 研修スケジュール
#
# **Day1**
# | 時程 | 章節 |
# | ---- | ---- |
# |  9:30 〜 9:50  |  0. イントロダクション  |
# |  9:50 〜 10:20  |  2. Google Colaboratory 実習  |
# |  10:20 〜 10:30  |   3. データの理解  |
# |  10:30 〜 12:00 |  4. Python 速習とテーブルデータの基本操作  |
# |  12:00 〜 13:00  |  昼休憩  |
# |  13:00 〜 13:20  |  5. 演習問題  |
# |  13:20 〜 14:30  |  7. 問題設定：Bank Marketing  |
# |  14:30 〜 15:40  |  10. モデル構築のための特徴量作成  |
# |  15:40 〜 16:30 |  11. モデルの精度を保証する実装   |
# |  16:30 〜 17:30  |  12. 説明可能な AI (XAI)  |
#
# **Day2**
# | 時程 | 章節 |
# | ---- | ---- |
# |  9:30 〜 9:40  |  0. イントロダクション  |
# |  9:40 〜 11:00  |  14. 時系列データの取り扱い方  |
# |  11:00 〜 12:00  |   15. 自己回帰型モデル  |
# |  12:00 〜 13:00  |  昼休憩  |
# |  13:00 〜 14:00  |  15. 自己回帰型モデル  |
# |  14:00 〜 14:40  |  18. 異常検知とは  |
# |  14:40 〜 15:40  |  19. 外れ値検知入門  |
# |  15:40 〜 16:30 |  21. 機械学習を用いた異常検知入門   |
# |  16:30 〜 17:20  |  23. 変化点検知入門  |
# |  17:20 〜 17:30  |  アウトロダクション  |
